# %%
import datetime, time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import GridSearchCV

from IPython.display import clear_output, display, HTML

# %%
# Ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %%
train = pd.read_csv("train_preprocessed.csv")
test = pd.read_csv("test_preprocessed.csv")
all_data = pd.read_csv("all_data_preprocessed.csv")

# %%
train_X = train.loc[:, train.columns != 'totals_totalTransactionRevenue']
train_y = train['totals_totalTransactionRevenue']

# %%
test_X = test.loc[:, test.columns != 'totals_totalTransactionRevenue']
test_y = test['totals_totalTransactionRevenue']

# %%
all_data_X = all_data.loc[:, all_data.columns != 'totals_totalTransactionRevenue']
all_data_y = all_data['totals_totalTransactionRevenue']

# %%
parameters = {  
    'hidden_layer_sizes': [(10,), (14, 7), (14, 7, 3)],
    'solver': ['adam', 'sgd'],
    'learning_rate' : ['constant', 'invscaling', 'adaptive'],
}

for key, values in parameters.items():
    print(key," - ", values)
# Out:
# hidden_layer_sizes  -  [(10,), (14, 7), (14, 7, 3)]
# solver  -  ['adam', 'sgd']
# learning_rate  -  ['constant', 'invscaling', 'adaptive']

# %%
start = time.time()

gridSearchResult = GridSearchCV(MLPRegressor(random_state = 0),
                                parameters, 
                                cv = 5, 
                                scoring='neg_mean_squared_error', 
                                verbose=5
                               ).fit(all_data_X, all_data_y)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
time_taken = "{:0>2}:{:0>2}:{:05.3f}".format(int(hours),int(minutes),seconds)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=adam ...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=adam, score=-146515834175871.7, total= 2.1min
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=adam ...
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.1min remaining:    0.0s
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=adam, score=-1111094410330587.8, total= 2.5min
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=adam ...
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  4.6min remaining:    0.0s
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=adam, score=-658019171663522.0, total= 3.2min
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=adam ...
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  7.9min remaining:    0.0s
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=adam, score=-2584588885066861.0, total= 4.6min
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=adam ...
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 12.5min remaining:    0.0s
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=adam, score=-488172739317188.9, total= 2.0min
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd, score=-1258945481523760.5, total=  56.0s
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd, score=-7794144179276029.0, total=  58.1s
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd, score=-2723642185538194.0, total=  57.4s
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd, score=-7120284269489518.0, total=  56.2s
# [CV] hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=constant, solver=sgd, score=-4499668357499772.0, total=  56.4s
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam .
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam, score=-146515834175871.7, total= 2.2min
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam .
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam, score=-1111094410330587.8, total= 2.5min
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam .
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam, score=-658019171663522.0, total= 3.2min
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam .
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam, score=-2584588885066861.0, total= 4.6min
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam .
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=adam, score=-488172739317188.9, total= 1.9min
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd ..
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd, score=-1.221776671309989e+92, total=  56.2s
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd ..
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd, score=-8.743822877998397e+91, total=  56.9s
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd ..
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd, score=-8.653887747119495e+91, total=  56.2s
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd ..
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd, score=-6.123893823527669e+94, total=  56.2s
# [CV] hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd ..
# [CV]  hidden_layer_sizes=(10,), learning_rate=invscaling, solver=sgd, score=-1.76010460863324e+91, total=  57.2s
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam ...
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam, score=-146515834175871.7, total= 2.0min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam ...
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam, score=-1111094410330587.8, total= 2.5min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam ...
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam, score=-658019171663522.0, total= 3.2min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam ...
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam, score=-2584588885066861.0, total= 4.6min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam ...
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=adam, score=-488172739317188.9, total= 1.9min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd, score=-1258942212559502.8, total= 5.3min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd, score=-7793982224993523.0, total= 5.2min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd, score=-2723388990587135.0, total= 5.2min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd, score=-7120100900656453.0, total= 5.2min
# [CV] hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd ....
# [CV]  hidden_layer_sizes=(10,), learning_rate=adaptive, solver=sgd, score=-4499523640823016.0, total= 5.2min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam, score=-214482848110969.6, total= 4.5min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam, score=-945170161755768.9, total= 3.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam, score=-583510473973682.4, total= 3.1min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam, score=-3171854886637639.5, total= 6.1min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=adam, score=-499951422717276.4, total= 3.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd, score=-1258957840367664.8, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd, score=-7793982257634085.0, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd, score=-2723432602632862.0, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd, score=-7120105162188091.0, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=constant, solver=sgd, score=-4499548518169882.5, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam, score=-214482848110969.6, total= 4.5min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam, score=-945170161755768.9, total= 3.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam, score=-583510473973682.4, total= 3.1min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam, score=-3171854886637639.5, total= 6.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=adam, score=-499951422717276.4, total= 3.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd, score=-1258940131702923.2, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd, score=-7794061535669188.0, total= 1.5min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd, score=-2723405136773671.0, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd, score=-7120103480390607.0, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=invscaling, solver=sgd, score=-4499525890998075.0, total= 1.4min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam, score=-214482848110969.6, total= 4.5min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam, score=-945170161755768.9, total= 3.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam, score=-583510473973682.4, total= 3.1min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam, score=-3171854886637639.5, total= 6.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam .
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=adam, score=-499951422717276.4, total= 3.0min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd, score=-1258941958934184.2, total= 7.7min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd, score=-7793982293877653.0, total= 7.7min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd, score=-2723388703715821.0, total= 7.9min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd, score=-7120100744168740.0, total= 7.6min
# [CV] hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd ..
# [CV]  hidden_layer_sizes=(14, 7), learning_rate=adaptive, solver=sgd, score=-4499523648113122.0, total= 7.6min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam, score=-145831240130485.62, total= 5.4min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam, score=-855889089909578.1, total= 5.5min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam, score=-602245715924268.8, total= 7.9min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam, score=-3244252271715552.0, total= 3.8min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=adam, score=-403950432054391.4, total= 6.5min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd, score=-1258932993017002.0, total= 1.6min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd, score=-7794273611435044.0, total= 1.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd, score=-2723424871145700.0, total= 1.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd, score=-7120166914873193.0, total= 1.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=constant, solver=sgd, score=-4499538977041984.0, total= 1.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam, score=-145831240130485.62, total= 5.5min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam, score=-855889089909578.1, total= 5.4min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam, score=-602245715924268.8, total= 7.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam, score=-3244252271715552.0, total= 3.8min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=adam, score=-403950432054391.4, total= 6.4min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd, score=-1258940537061368.5, total= 1.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd, score=-7794064641493894.0, total= 1.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd, score=-2723403531286927.5, total= 1.6min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd, score=-7120110301168228.0, total= 1.6min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=invscaling, solver=sgd, score=-4499531210994193.0, total= 1.6min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam, score=-145831240130485.62, total= 5.3min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam, score=-855889089909578.1, total= 5.3min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam, score=-602245715924268.8, total= 7.7min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam, score=-3244252271715552.0, total= 3.8min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=adam, score=-403950432054391.4, total= 6.4min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd, score=-1258942010489169.8, total= 9.1min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd, score=-7793982212999622.0, total= 9.1min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd, score=-2723389144861437.5, total= 9.2min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd, score=-7120100899850978.0, total= 9.1min
# [CV] hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd
# [CV]  hidden_layer_sizes=(14, 7, 3), learning_rate=adaptive, solver=sgd, score=-4499523642554135.5, total= 9.2min
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed: 342.2min finished

# %%
results_df = pd.DataFrame.from_dict(gridSearchResult.cv_results_)
results_df.T
# Out:
#                                                                                                      0  \
# mean_fit_time             171.473
# std_fit_time              57.9775
# mean_score_time           0.608599
# std_score_time            0.121985
# param_hidden_layer_sizes  (10,)
# param_learning_rate       constant
# param_solver              adam
# params                    {'hidden_layer_sizes': (10,), 'learning_rate': 'constant', 'solver': 'adam'}
# split0_test_score        -1.46516e+14
# split1_test_score        -1.11109e+15
# split2_test_score        -6.58019e+14
# split3_test_score        -2.58459e+15
# split4_test_score        -4.88173e+14
# mean_test_score          -9.97678e+14
# std_test_score            8.52126e+14
# rank_test_score           1
# split0_train_score       -1.1395e+15
# split1_train_score       -9.64247e+14
# split2_train_score       -9.99531e+14
# split3_train_score       -5.40685e+14
# split4_train_score       -1.04335e+15
# mean_train_score         -9.37463e+14
# std_train_score           2.06898e+14
#
#                                                                                                     1  \
# mean_fit_time             56.7295
# std_fit_time              0.78936
# mean_score_time           0.211902
# std_score_time            0.0022918
# param_hidden_layer_sizes  (10,)
# param_learning_rate       constant
# param_solver              sgd
# params                    {'hidden_layer_sizes': (10,), 'learning_rate': 'constant', 'solver': 'sgd'}
# split0_test_score        -1.25895e+15
# split1_test_score        -7.79414e+15
# split2_test_score        -2.72364e+15
# split3_test_score        -7.12028e+15
# split4_test_score        -4.49967e+15
# mean_test_score          -4.67934e+15
# std_test_score            2.49865e+15
# rank_test_score           17
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90066e+15
# split2_train_score       -5.16833e+15
# split3_train_score       -4.0691e+15
# split4_train_score       -4.72425e+15
# mean_train_score         -4.67932e+15
# std_train_score           6.24615e+14
#
#                                                                                                        2  \
# mean_fit_time             171.908
# std_fit_time              57.2365
# mean_score_time           0.6054
# std_score_time            0.119995
# param_hidden_layer_sizes  (10,)
# param_learning_rate       invscaling
# param_solver              adam
# params                    {'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling', 'solver': 'adam'}
# split0_test_score        -1.46516e+14
# split1_test_score        -1.11109e+15
# split2_test_score        -6.58019e+14
# split3_test_score        -2.58459e+15
# split4_test_score        -4.88173e+14
# mean_test_score          -9.97678e+14
# std_test_score            8.52126e+14
# rank_test_score           1
# split0_train_score       -1.1395e+15
# split1_train_score       -9.64247e+14
# split2_train_score       -9.99531e+14
# split3_train_score       -5.40685e+14
# split4_train_score       -1.04335e+15
# mean_train_score         -9.37463e+14
# std_train_score           2.06898e+14
#
#                                                                                                       3  \
# mean_fit_time             56.4341
# std_fit_time              0.430039
# mean_score_time           0.2122
# std_score_time            0.00820096
# param_hidden_layer_sizes  (10,)
# param_learning_rate       invscaling
# param_solver              sgd
# params                    {'hidden_layer_sizes': (10,), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# split0_test_score        -1.22178e+92
# split1_test_score        -8.74382e+91
# split2_test_score        -8.65389e+91
# split3_test_score        -6.12389e+94
# split4_test_score        -1.7601e+91
# mean_test_score          -1.23105e+94
# std_test_score            2.44642e+94
# rank_test_score           18
# split0_train_score       -1.22178e+92
# split1_train_score       -8.74382e+91
# split2_train_score       -8.65389e+91
# split3_train_score       -6.12389e+94
# split4_train_score       -1.7601e+91
# mean_train_score         -1.23105e+94
# std_train_score           2.44642e+94
#
#                                                                                                      4  \
# mean_fit_time             170.877
# std_fit_time              59.2039
# mean_score_time           0.646101
# std_score_time            0.185598
# param_hidden_layer_sizes  (10,)
# param_learning_rate       adaptive
# param_solver              adam
# params                    {'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# split0_test_score        -1.46516e+14
# split1_test_score        -1.11109e+15
# split2_test_score        -6.58019e+14
# split3_test_score        -2.58459e+15
# split4_test_score        -4.88173e+14
# mean_test_score          -9.97678e+14
# std_test_score            8.52126e+14
# rank_test_score           1
# split0_train_score       -1.1395e+15
# split1_train_score       -9.64247e+14
# split2_train_score       -9.99531e+14
# split3_train_score       -5.40685e+14
# split4_train_score       -1.04335e+15
# mean_train_score         -9.37463e+14
# std_train_score           2.06898e+14
#
#                                                                                                     5  \
# mean_fit_time             311.865
# std_fit_time              2.55602
# mean_score_time           0.205299
# std_score_time            0.00654598
# param_hidden_layer_sizes  (10,)
# param_learning_rate       adaptive
# param_solver              sgd
# params                    {'hidden_layer_sizes': (10,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# split0_test_score        -1.25894e+15
# split1_test_score        -7.79398e+15
# split2_test_score        -2.72339e+15
# split3_test_score        -7.1201e+15
# split4_test_score        -4.49952e+15
# mean_test_score          -4.67919e+15
# std_test_score            2.49862e+15
# rank_test_score           12
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90049e+15
# split2_train_score       -5.16813e+15
# split3_train_score       -4.06896e+15
# split4_train_score       -4.7241e+15
# mean_train_score         -4.67918e+15
# std_train_score           6.24655e+14
#
#                                                                                                        6  \
# mean_fit_time             235.681
# std_fit_time              73.5269
# mean_score_time           1.0845
# std_score_time            0.118197
# param_hidden_layer_sizes  (14, 7)
# param_learning_rate       constant
# param_solver              adam
# params                    {'hidden_layer_sizes': (14, 7), 'learning_rate': 'constant', 'solver': 'adam'}
# split0_test_score        -2.14483e+14
# split1_test_score        -9.4517e+14
# split2_test_score        -5.8351e+14
# split3_test_score        -3.17185e+15
# split4_test_score        -4.99951e+14
# mean_test_score          -1.08299e+15
# std_test_score            1.07015e+15
# rank_test_score           7
# split0_train_score       -1.16918e+15
# split1_train_score       -9.30697e+14
# split2_train_score       -1.11736e+15
# split3_train_score       -6.70138e+14
# split4_train_score       -1.14758e+15
# mean_train_score         -1.00699e+15
# std_train_score           1.88436e+14
#
#                                                                                                       7  \
# mean_fit_time             84.5034
# std_fit_time              1.49703
# mean_score_time           0.2968
# std_score_time            0.00937397
# param_hidden_layer_sizes  (14, 7)
# param_learning_rate       constant
# param_solver              sgd
# params                    {'hidden_layer_sizes': (14, 7), 'learning_rate': 'constant', 'solver': 'sgd'}
# split0_test_score        -1.25896e+15
# split1_test_score        -7.79398e+15
# split2_test_score        -2.72343e+15
# split3_test_score        -7.12011e+15
# split4_test_score        -4.49955e+15
# mean_test_score          -4.6792e+15
# std_test_score            2.49861e+15
# rank_test_score           13
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90049e+15
# split2_train_score       -5.16816e+15
# split3_train_score       -4.06896e+15
# split4_train_score       -4.72413e+15
# mean_train_score         -4.6792e+15
# std_train_score           6.2466e+14
#
#                                                                                                          8  \
# mean_fit_time             234.151
# std_fit_time              71.2884
# mean_score_time           1.0588
# std_score_time            0.107468
# param_hidden_layer_sizes  (14, 7)
# param_learning_rate       invscaling
# param_solver              adam
# params                    {'hidden_layer_sizes': (14, 7), 'learning_rate': 'invscaling', 'solver': 'adam'}
# split0_test_score        -2.14483e+14
# split1_test_score        -9.4517e+14
# split2_test_score        -5.8351e+14
# split3_test_score        -3.17185e+15
# split4_test_score        -4.99951e+14
# mean_test_score          -1.08299e+15
# std_test_score            1.07015e+15
# rank_test_score           7
# split0_train_score       -1.16918e+15
# split1_train_score       -9.30697e+14
# split2_train_score       -1.11736e+15
# split3_train_score       -6.70138e+14
# split4_train_score       -1.14758e+15
# mean_train_score         -1.00699e+15
# std_train_score           1.88436e+14
#
#                                                                                                         9  \
# mean_fit_time             84.2874
# std_fit_time              2.93677
# mean_score_time           0.282304
# std_score_time            0.00802667
# param_hidden_layer_sizes  (14, 7)
# param_learning_rate       invscaling
# param_solver              sgd
# params                    {'hidden_layer_sizes': (14, 7), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# split0_test_score        -1.25894e+15
# split1_test_score        -7.79406e+15
# split2_test_score        -2.72341e+15
# split3_test_score        -7.1201e+15
# split4_test_score        -4.49953e+15
# mean_test_score          -4.67921e+15
# std_test_score            2.49864e+15
# rank_test_score           14
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90056e+15
# split2_train_score       -5.16814e+15
# split3_train_score       -4.06896e+15
# split4_train_score       -4.7241e+15
# mean_train_score         -4.6792e+15
# std_train_score           6.24639e+14
#
#                                                                                                       10  \
# mean_fit_time             233.699
# std_fit_time              70.2439
# mean_score_time           1.0632
# std_score_time            0.100514
# param_hidden_layer_sizes  (14, 7)
# param_learning_rate       adaptive
# param_solver              adam
# params                    {'hidden_layer_sizes': (14, 7), 'learning_rate': 'adaptive', 'solver': 'adam'}
# split0_test_score        -2.14483e+14
# split1_test_score        -9.4517e+14
# split2_test_score        -5.8351e+14
# split3_test_score        -3.17185e+15
# split4_test_score        -4.99951e+14
# mean_test_score          -1.08299e+15
# std_test_score            1.07015e+15
# rank_test_score           7
# split0_train_score       -1.16918e+15
# split1_train_score       -9.30697e+14
# split2_train_score       -1.11736e+15
# split3_train_score       -6.70138e+14
# split4_train_score       -1.14758e+15
# mean_train_score         -1.00699e+15
# std_train_score           1.88436e+14
#
#                                                                                                      11  \
# mean_fit_time             461.666
# std_fit_time              7.3331
# mean_score_time           0.289
# std_score_time            0.0100942
# param_hidden_layer_sizes  (14, 7)
# param_learning_rate       adaptive
# param_solver              sgd
# params                    {'hidden_layer_sizes': (14, 7), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# split0_test_score        -1.25894e+15
# split1_test_score        -7.79398e+15
# split2_test_score        -2.72339e+15
# split3_test_score        -7.1201e+15
# split4_test_score        -4.49952e+15
# mean_test_score          -4.67919e+15
# std_test_score            2.49862e+15
# rank_test_score           10
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90049e+15
# split2_train_score       -5.16813e+15
# split3_train_score       -4.06896e+15
# split4_train_score       -4.7241e+15
# mean_train_score         -4.67918e+15
# std_train_score           6.24655e+14
#
#                                                                                                          12  \
# mean_fit_time             347.419
# std_fit_time              80.3497
# mean_score_time           1.1049
# std_score_time            0.065173
# param_hidden_layer_sizes  (14, 7, 3)
# param_learning_rate       constant
# param_solver              adam
# params                    {'hidden_layer_sizes': (14, 7, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# split0_test_score        -1.45831e+14
# split1_test_score        -8.55889e+14
# split2_test_score        -6.02246e+14
# split3_test_score        -3.24425e+15
# split4_test_score        -4.0395e+14
# mean_test_score          -1.05043e+15
# std_test_score            1.12141e+15
# rank_test_score           4
# split0_train_score       -1.20254e+15
# split1_train_score       -9.5837e+14
# split2_train_score       -1.14712e+15
# split3_train_score       -7.19458e+14
# split4_train_score       -1.08517e+15
# mean_train_score         -1.02253e+15
# std_train_score           1.71942e+14
#
#                                                                                                         13  \
# mean_fit_time             99.3869
# std_fit_time              0.875564
# mean_score_time           0.360998
# std_score_time            0.0924432
# param_hidden_layer_sizes  (14, 7, 3)
# param_learning_rate       constant
# param_solver              sgd
# params                    {'hidden_layer_sizes': (14, 7, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# split0_test_score        -1.25893e+15
# split1_test_score        -7.79427e+15
# split2_test_score        -2.72342e+15
# split3_test_score        -7.12017e+15
# split4_test_score        -4.49954e+15
# mean_test_score          -4.67927e+15
# std_test_score            2.4987e+15
# rank_test_score           16
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90076e+15
# split2_train_score       -5.16815e+15
# split3_train_score       -4.069e+15
# split4_train_score       -4.72412e+15
# mean_train_score         -4.67926e+15
# std_train_score           6.24583e+14
#
#                                                                                                            14  \
# mean_fit_time             344.851
# std_fit_time              76.2834
# mean_score_time           1.0994
# std_score_time            0.0595743
# param_hidden_layer_sizes  (14, 7, 3)
# param_learning_rate       invscaling
# param_solver              adam
# params                    {'hidden_layer_sizes': (14, 7, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# split0_test_score        -1.45831e+14
# split1_test_score        -8.55889e+14
# split2_test_score        -6.02246e+14
# split3_test_score        -3.24425e+15
# split4_test_score        -4.0395e+14
# mean_test_score          -1.05043e+15
# std_test_score            1.12141e+15
# rank_test_score           4
# split0_train_score       -1.20254e+15
# split1_train_score       -9.5837e+14
# split2_train_score       -1.14712e+15
# split3_train_score       -7.19458e+14
# split4_train_score       -1.08517e+15
# mean_train_score         -1.02253e+15
# std_train_score           1.71942e+14
#
#                                                                                                           15  \
# mean_fit_time             99.188
# std_fit_time              1.81865
# mean_score_time           0.313601
# std_score_time            0.0160853
# param_hidden_layer_sizes  (14, 7, 3)
# param_learning_rate       invscaling
# param_solver              sgd
# params                    {'hidden_layer_sizes': (14, 7, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# split0_test_score        -1.25894e+15
# split1_test_score        -7.79406e+15
# split2_test_score        -2.7234e+15
# split3_test_score        -7.12011e+15
# split4_test_score        -4.49953e+15
# mean_test_score          -4.67921e+15
# std_test_score            2.49864e+15
# rank_test_score           15
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90056e+15
# split2_train_score       -5.16814e+15
# split3_train_score       -4.06896e+15
# split4_train_score       -4.72411e+15
# mean_train_score         -4.6792e+15
# std_train_score           6.24638e+14
#
#                                                                                                          16  \
# mean_fit_time             340.753
# std_fit_time              77.4109
# mean_score_time           1.088
# std_score_time            0.0574268
# param_hidden_layer_sizes  (14, 7, 3)
# param_learning_rate       adaptive
# param_solver              adam
# params                    {'hidden_layer_sizes': (14, 7, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# split0_test_score        -1.45831e+14
# split1_test_score        -8.55889e+14
# split2_test_score        -6.02246e+14
# split3_test_score        -3.24425e+15
# split4_test_score        -4.0395e+14
# mean_test_score          -1.05043e+15
# std_test_score            1.12141e+15
# rank_test_score           4
# split0_train_score       -1.20254e+15
# split1_train_score       -9.5837e+14
# split2_train_score       -1.14712e+15
# split3_train_score       -7.19458e+14
# split4_train_score       -1.08517e+15
# mean_train_score         -1.02253e+15
# std_train_score           1.71942e+14
#
#                                                                                                         17
# mean_fit_time             547.509
# std_fit_time              2.41396
# mean_score_time           0.318399
# std_score_time            0.00691785
# param_hidden_layer_sizes  (14, 7, 3)
# param_learning_rate       adaptive
# param_solver              sgd
# params                    {'hidden_layer_sizes': (14, 7, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# split0_test_score        -1.25894e+15
# split1_test_score        -7.79398e+15
# split2_test_score        -2.72339e+15
# split3_test_score        -7.1201e+15
# split4_test_score        -4.49952e+15
# mean_test_score          -4.67919e+15
# std_test_score            2.49862e+15
# rank_test_score           11
# split0_train_score       -5.53425e+15
# split1_train_score       -3.90049e+15
# split2_train_score       -5.16813e+15
# split3_train_score       -4.06896e+15
# split4_train_score       -4.7241e+15
# mean_train_score         -4.67918e+15
# std_train_score           6.24655e+14

# %%
# Results with Rank 1
rank_one = results_df[results_df['rank_test_score'] == 1][['params', 'mean_fit_time', 'std_fit_time','mean_train_score','std_train_score', 'mean_test_score', 'std_test_score']]

# %%
pd.concat([rank_one["params"].apply(pd.Series), rank_one], axis=1).drop(columns = ['params']).T
# Out:
#                               0            2            4
# hidden_layer_sizes  (10,)        (10,)        (10,)
# learning_rate       constant     invscaling   adaptive
# solver              adam         adam         adam
# mean_fit_time       171.473      171.908      170.877
# std_fit_time        57.9775      57.2365      59.2039
# mean_train_score   -9.37463e+14 -9.37463e+14 -9.37463e+14
# std_train_score     2.06898e+14  2.06898e+14  2.06898e+14
# mean_test_score    -9.97678e+14 -9.97678e+14 -9.97678e+14
# std_test_score      8.52126e+14  8.52126e+14  8.52126e+14

# %%
gridSearchResult.best_estimator_
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=0, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
start = time.time()

model = MLPRegressor(activation='relu',
                     hidden_layer_sizes=(10,), 
                     learning_rate='constant'
                    ).fit(train_X, train_y)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print("Time Taken: {:0>2}:{:0>2}:{:05.3f}".format(int(hours),int(minutes),seconds))

# %%
predictions = pd.Series(model.predict(test_X))

# %%
print("Mean Squared Error:", (mean_squared_error(test_y, predictions))**0.5)
print("Time Taken to Fit:", time_taken)
# Out:
# Mean Squared Error: 21378720.967687212
# Time Taken to Fit: 00:03:50.756

# %%
fig = plt.figure(figsize=(30,8))
ax = plt.axes()

ax.plot(predictions.index, predictions, color = 'blue', label='Prediction')
ax.scatter(test_y.index, test_y, color = 'red', label='Real Value')

ax.legend(loc='best')
plt.show()

# %%
start = time.time()

model = MLPRegressor(activation='relu',
                     hidden_layer_sizes=(10,), 
                     learning_rate='invscaling'
                    ).fit(train_X, train_y)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
time_taken = "{:0>2}:{:0>2}:{:05.3f}".format(int(hours),int(minutes),seconds)

# %%
predictions = pd.Series(model.predict(test_X))

# %%
print("Mean Squared Error:", (mean_squared_error(test_y, predictions))**0.5)
print("Time Taken to Fit:", time_taken)
# Out:
# Mean Squared Error: 21208747.239391055
# Time Taken to Fit: 00:05:25.121

# %%
fig = plt.figure(figsize=(30,8))
ax = plt.axes()

ax.plot(predictions.index, predictions, color = 'blue', label='Prediction')
ax.scatter(test_y.index, test_y, color = 'red', label='Real Value')

ax.legend(loc='best')
plt.show()

# %%
start = time.time()

model = MLPRegressor(activation='relu',
                     hidden_layer_sizes=(10,), 
                     learning_rate='adaptive'
                    ).fit(train_X, train_y)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
time_taken = "{:0>2}:{:0>2}:{:05.3f}".format(int(hours),int(minutes),seconds)

# %%
predictions = pd.Series(model.predict(test_X))

# %%
print("Mean Squared Error:", (mean_squared_error(test_y, predictions))**0.5)
print("Time Taken to Fit:", time_taken)
# Out:
# Mean Squared Error: 24197144.016007423
# Time Taken to Fit: 00:08:0.438

# %%
fig = plt.figure(figsize=(30,8))
ax = plt.axes()

ax.plot(predictions.index, predictions, color = 'blue', label='Prediction')
ax.scatter(test_y.index, test_y, color = 'red', label='Real Value')

ax.legend(loc='best')
plt.show()
