# %%
import datetime, time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import GridSearchCV

from IPython.display import clear_output, display, HTML

# %%
# Ignore warning
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %%
train = pd.read_csv("train_preprocessed.csv")
test = pd.read_csv("test_preprocessed.csv")
all_data = pd.read_csv("all_data_preprocessed.csv")

# %%
train_X = train.loc[:, train.columns != 'totals_totalTransactionRevenue']
train_y = train['totals_totalTransactionRevenue']
test_X = test.loc[:, test.columns != 'totals_totalTransactionRevenue']
test_y = test['totals_totalTransactionRevenue']
all_data_X = all_data.loc[:, all_data.columns != 'totals_totalTransactionRevenue']
all_data_y = all_data['totals_totalTransactionRevenue']

# %%
parameters = {
    'n_estimators': [est for est in range(2, 11, 2)],
    'max_depth': [depth for depth in range(2, 20, 2)],
    'min_samples_split': [min_samples for min_samples in range(200, 2001, 200)]
}

for key, values in parameters.items():
    print(key," - ", values)
# Out:
# n_estimators  -  [2, 4, 6, 8, 10]
# max_depth  -  [2, 4, 6, 8, 10, 12, 14, 16, 18]
# min_samples_split  -  [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]

# %%
start = time.time()

gridSearchResult = GridSearchCV(RandomForestRegressor(random_state = 0),
                                parameters, 
                                cv=5, 
                                scoring='neg_mean_squared_error', 
                                verbose=5
                               ).fit(all_data_X, all_data_y)
clear_output()
end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print("Time Taken: {:0>2}:{:0>2}:{:05.3f}".format(int(hours),int(minutes),seconds))
# Out:
# Time Taken: 19:27:49.254

# %%
# Show all results
results_df = pd.DataFrame.from_dict(gridSearchResult.cv_results_)
results_df.T
# Out:
#                                                                                      0  \
# mean_fit_time            3.71981
# std_fit_time             0.0661689
# mean_score_time          0.0671906
# std_score_time           0.000745233
# param_max_depth          2
# param_min_samples_split  200
# param_n_estimators       2
# params                   {'max_depth': 2, 'min_samples_split': 200, 'n_estimators': 2}
# split0_test_score       -5.09289e+14
# split1_test_score       -2.88362e+15
# split2_test_score       -1.62192e+15
# split3_test_score       -3.926e+15
# split4_test_score       -6.58881e+14
# mean_test_score         -1.91994e+15
# std_test_score           1.31316e+15
# rank_test_score          441
# split0_train_score      -1.76258e+15
# split1_train_score      -1.35792e+15
# split2_train_score      -1.28842e+15
# split3_train_score      -1.10149e+15
# split4_train_score      -1.44118e+15
# mean_train_score        -1.39032e+15
# std_train_score          2.17265e+14
#
#                                                                                      1  \
# mean_fit_time            6.9558
# std_fit_time             0.020506
# mean_score_time          0.0785968
# std_score_time           0.00241861
# param_max_depth          2
# param_min_samples_split  200
# param_n_estimators       4
# params                   {'max_depth': 2, 'min_samples_split': 200, 'n_estimators': 4}
# split0_test_score       -4.50467e+14
# split1_test_score       -2.39396e+15
# split2_test_score       -1.57185e+15
# split3_test_score       -3.37624e+15
# split4_test_score       -5.4402e+14
# mean_test_score         -1.66731e+15
# std_test_score           1.11356e+15
# rank_test_score          357
# split0_train_score      -1.53017e+15
# split1_train_score      -1.12127e+15
# split2_train_score      -1.23887e+15
# split3_train_score      -8.08056e+14
# split4_train_score      -1.21271e+15
# mean_train_score        -1.18222e+15
# std_train_score          2.31916e+14
#
#                                                                                      2  \
# mean_fit_time            10.1852
# std_fit_time             0.0958963
# mean_score_time          0.090395
# std_score_time           0.00382538
# param_max_depth          2
# param_min_samples_split  200
# param_n_estimators       6
# params                   {'max_depth': 2, 'min_samples_split': 200, 'n_estimators': 6}
# split0_test_score       -5.12626e+14
# split1_test_score       -2.68615e+15
# split2_test_score       -1.44415e+15
# split3_test_score       -3.0963e+15
# split4_test_score       -6.13805e+14
# mean_test_score         -1.6706e+15
# std_test_score           1.05574e+15
# rank_test_score          373
# split0_train_score      -1.60386e+15
# split1_train_score      -1.09866e+15
# split2_train_score      -1.2695e+15
# split3_train_score      -9.02818e+14
# split4_train_score      -1.28395e+15
# mean_train_score        -1.23176e+15
# std_train_score          2.31743e+14
#
#                                                                                      3  \
# mean_fit_time            13.481
# std_fit_time             0.204934
# mean_score_time          0.0951898
# std_score_time           0.00417067
# param_max_depth          2
# param_min_samples_split  200
# param_n_estimators       8
# params                   {'max_depth': 2, 'min_samples_split': 200, 'n_estimators': 8}
# split0_test_score       -4.47094e+14
# split1_test_score       -2.71544e+15
# split2_test_score       -1.48425e+15
# split3_test_score       -2.93467e+15
# split4_test_score       -6.98748e+14
# mean_test_score         -1.65604e+15
# std_test_score           1.01634e+15
# rank_test_score          347
# split0_train_score      -1.48606e+15
# split1_train_score      -1.14631e+15
# split2_train_score      -1.31698e+15
# split3_train_score      -9.41899e+14
# split4_train_score      -1.37131e+15
# mean_train_score        -1.25251e+15
# std_train_score          1.90038e+14
#
#                                                                                       4  \
# mean_fit_time            16.7074
# std_fit_time             0.04302
# mean_score_time          0.105392
# std_score_time           0.00643417
# param_max_depth          2
# param_min_samples_split  200
# param_n_estimators       10
# params                   {'max_depth': 2, 'min_samples_split': 200, 'n_estimators': 10}
# split0_test_score       -4.38745e+14
# split1_test_score       -2.66562e+15
# split2_test_score       -1.46375e+15
# split3_test_score       -2.7681e+15
# split4_test_score       -6.60619e+14
# mean_test_score         -1.59937e+15
# std_test_score           9.74629e+14
# rank_test_score          321
# split0_train_score      -1.44603e+15
# split1_train_score      -1.12627e+15
# split2_train_score      -1.31983e+15
# split3_train_score      -9.54534e+14
# split4_train_score      -1.39719e+15
# mean_train_score        -1.24877e+15
# std_train_score          1.83067e+14
#
#                                                                                      5  \
# mean_fit_time            3.6818
# std_fit_time             0.0515402
# mean_score_time          0.0685952
# std_score_time           0.00120281
# param_max_depth          2
# param_min_samples_split  400
# param_n_estimators       2
# params                   {'max_depth': 2, 'min_samples_split': 400, 'n_estimators': 2}
# split0_test_score       -5.09289e+14
# split1_test_score       -2.88362e+15
# split2_test_score       -1.62192e+15
# split3_test_score       -3.926e+15
# split4_test_score       -6.58881e+14
# mean_test_score         -1.91994e+15
# std_test_score           1.31316e+15
# rank_test_score          441
# split0_train_score      -1.76258e+15
# split1_train_score      -1.35792e+15
# split2_train_score      -1.28842e+15
# split3_train_score      -1.10149e+15
# split4_train_score      -1.44118e+15
# mean_train_score        -1.39032e+15
# std_train_score          2.17265e+14
#
#                                                                                      6  \
# mean_fit_time            6.9464
# std_fit_time             0.0413878
# mean_score_time          0.0783973
# std_score_time           0.00162728
# param_max_depth          2
# param_min_samples_split  400
# param_n_estimators       4
# params                   {'max_depth': 2, 'min_samples_split': 400, 'n_estimators': 4}
# split0_test_score       -4.50467e+14
# split1_test_score       -2.39396e+15
# split2_test_score       -1.57185e+15
# split3_test_score       -3.37624e+15
# split4_test_score       -5.4402e+14
# mean_test_score         -1.66731e+15
# std_test_score           1.11356e+15
# rank_test_score          357
# split0_train_score      -1.53017e+15
# split1_train_score      -1.12127e+15
# split2_train_score      -1.23887e+15
# split3_train_score      -8.08056e+14
# split4_train_score      -1.21271e+15
# mean_train_score        -1.18222e+15
# std_train_score          2.31916e+14
#
#                                                                                      7  \
# mean_fit_time            10.1784
# std_fit_time             0.0441727
# mean_score_time          0.0845924
# std_score_time           0.00185552
# param_max_depth          2
# param_min_samples_split  400
# param_n_estimators       6
# params                   {'max_depth': 2, 'min_samples_split': 400, 'n_estimators': 6}
# split0_test_score       -5.12626e+14
# split1_test_score       -2.68615e+15
# split2_test_score       -1.44415e+15
# split3_test_score       -3.0963e+15
# split4_test_score       -6.13805e+14
# mean_test_score         -1.6706e+15
# std_test_score           1.05574e+15
# rank_test_score          373
# split0_train_score      -1.60386e+15
# split1_train_score      -1.09866e+15
# split2_train_score      -1.2695e+15
# split3_train_score      -9.02818e+14
# split4_train_score      -1.28395e+15
# mean_train_score        -1.23176e+15
# std_train_score          2.31743e+14
#
#                                                                                      8  \
# mean_fit_time            13.4094
# std_fit_time             0.0532117
# mean_score_time          0.0951925
# std_score_time           0.00239752
# param_max_depth          2
# param_min_samples_split  400
# param_n_estimators       8
# params                   {'max_depth': 2, 'min_samples_split': 400, 'n_estimators': 8}
# split0_test_score       -4.47094e+14
# split1_test_score       -2.71544e+15
# split2_test_score       -1.48425e+15
# split3_test_score       -2.93467e+15
# split4_test_score       -6.98748e+14
# mean_test_score         -1.65604e+15
# std_test_score           1.01634e+15
# rank_test_score          347
# split0_train_score      -1.48606e+15
# split1_train_score      -1.14631e+15
# split2_train_score      -1.31698e+15
# split3_train_score      -9.41899e+14
# split4_train_score      -1.37131e+15
# mean_train_score        -1.25251e+15
# std_train_score          1.90038e+14
#
#                                                                                       9  \
# mean_fit_time            16.707
# std_fit_time             0.108927
# mean_score_time          0.10319
# std_score_time           0.00511428
# param_max_depth          2
# param_min_samples_split  400
# param_n_estimators       10
# params                   {'max_depth': 2, 'min_samples_split': 400, 'n_estimators': 10}
# split0_test_score       -4.38745e+14
# split1_test_score       -2.66562e+15
# split2_test_score       -1.46375e+15
# split3_test_score       -2.7681e+15
# split4_test_score       -6.60619e+14
# mean_test_score         -1.59937e+15
# std_test_score           9.74629e+14
# rank_test_score          321
# split0_train_score      -1.44603e+15
# split1_train_score      -1.12627e+15
# split2_train_score      -1.31983e+15
# split3_train_score      -9.54534e+14
# split4_train_score      -1.39719e+15
# mean_train_score        -1.24877e+15
# std_train_score          1.83067e+14
#
#                                                                                     10  \
# mean_fit_time            3.69161
# std_fit_time             0.0646115
# mean_score_time          0.0675866
# std_score_time           0.00174421
# param_max_depth          2
# param_min_samples_split  600
# param_n_estimators       2
# params                   {'max_depth': 2, 'min_samples_split': 600, 'n_estimators': 2}
# split0_test_score       -5.09289e+14
# split1_test_score       -2.88362e+15
# split2_test_score       -1.62192e+15
# split3_test_score       -3.926e+15
# split4_test_score       -6.58881e+14
# mean_test_score         -1.91994e+15
# std_test_score           1.31316e+15
# rank_test_score          441
# split0_train_score      -1.76258e+15
# split1_train_score      -1.35792e+15
# split2_train_score      -1.28842e+15
# split3_train_score      -1.10149e+15
# split4_train_score      -1.44118e+15
# mean_train_score        -1.39032e+15
# std_train_score          2.17265e+14
#
#                                                                                     11  \
# mean_fit_time            6.92141
# std_fit_time             0.0345222
# mean_score_time          0.0773892
# std_score_time           0.00135589
# param_max_depth          2
# param_min_samples_split  600
# param_n_estimators       4
# params                   {'max_depth': 2, 'min_samples_split': 600, 'n_estimators': 4}
# split0_test_score       -4.50467e+14
# split1_test_score       -2.39396e+15
# split2_test_score       -1.57185e+15
# split3_test_score       -3.37624e+15
# split4_test_score       -5.4402e+14
# mean_test_score         -1.66731e+15
# std_test_score           1.11356e+15
# rank_test_score          357
# split0_train_score      -1.53017e+15
# split1_train_score      -1.12127e+15
# split2_train_score      -1.23887e+15
# split3_train_score      -8.08056e+14
# split4_train_score      -1.21271e+15
# mean_train_score        -1.18222e+15
# std_train_score          2.31916e+14
#
#                                                                                     12  \
# mean_fit_time            10.1688
# std_fit_time             0.0654037
# mean_score_time          0.0847908
# std_score_time           0.0020432
# param_max_depth          2
# param_min_samples_split  600
# param_n_estimators       6
# params                   {'max_depth': 2, 'min_samples_split': 600, 'n_estimators': 6}
# split0_test_score       -5.12626e+14
# split1_test_score       -2.68615e+15
# split2_test_score       -1.44415e+15
# split3_test_score       -3.0963e+15
# split4_test_score       -6.13805e+14
# mean_test_score         -1.6706e+15
# std_test_score           1.05574e+15
# rank_test_score          373
# split0_train_score      -1.60386e+15
# split1_train_score      -1.09866e+15
# split2_train_score      -1.2695e+15
# split3_train_score      -9.02818e+14
# split4_train_score      -1.28395e+15
# mean_train_score        -1.23176e+15
# std_train_score          2.31743e+14
#
#                                                                                     13  \
# mean_fit_time            13.4866
# std_fit_time             0.240451
# mean_score_time          0.0931924
# std_score_time           0.00319117
# param_max_depth          2
# param_min_samples_split  600
# param_n_estimators       8
# params                   {'max_depth': 2, 'min_samples_split': 600, 'n_estimators': 8}
# split0_test_score       -4.47094e+14
# split1_test_score       -2.71544e+15
# split2_test_score       -1.48425e+15
# split3_test_score       -2.93467e+15
# split4_test_score       -6.98748e+14
# mean_test_score         -1.65604e+15
# std_test_score           1.01634e+15
# rank_test_score          347
# split0_train_score      -1.48606e+15
# split1_train_score      -1.14631e+15
# split2_train_score      -1.31698e+15
# split3_train_score      -9.41899e+14
# split4_train_score      -1.37131e+15
# mean_train_score        -1.25251e+15
# std_train_score          1.90038e+14
#
#                                                                                      14  \
# mean_fit_time            16.6692
# std_fit_time             0.0899168
# mean_score_time          0.107193
# std_score_time           0.00462146
# param_max_depth          2
# param_min_samples_split  600
# param_n_estimators       10
# params                   {'max_depth': 2, 'min_samples_split': 600, 'n_estimators': 10}
# split0_test_score       -4.38745e+14
# split1_test_score       -2.66562e+15
# split2_test_score       -1.46375e+15
# split3_test_score       -2.7681e+15
# split4_test_score       -6.60619e+14
# mean_test_score         -1.59937e+15
# std_test_score           9.74629e+14
# rank_test_score          321
# split0_train_score      -1.44603e+15
# split1_train_score      -1.12627e+15
# split2_train_score      -1.31983e+15
# split3_train_score      -9.54534e+14
# split4_train_score      -1.39719e+15
# mean_train_score        -1.24877e+15
# std_train_score          1.83067e+14
#
#                                                                                     15  \
# mean_fit_time            3.70641
# std_fit_time             0.0433366
# mean_score_time          0.0683892
# std_score_time           0.0025795
# param_max_depth          2
# param_min_samples_split  800
# param_n_estimators       2
# params                   {'max_depth': 2, 'min_samples_split': 800, 'n_estimators': 2}
# split0_test_score       -5.09289e+14
# split1_test_score       -2.88362e+15
# split2_test_score       -1.62192e+15
# split3_test_score       -3.926e+15
# split4_test_score       -6.58881e+14
# mean_test_score         -1.91994e+15
# std_test_score           1.31316e+15
# rank_test_score          441
# split0_train_score      -1.76258e+15
# split1_train_score      -1.35792e+15
# split2_train_score      -1.28842e+15
# split3_train_score      -1.10149e+15
# split4_train_score      -1.44118e+15
# mean_train_score        -1.39032e+15
# std_train_score          2.17265e+14
#
#                                                                                     16  \
# mean_fit_time            6.94141
# std_fit_time             0.0148527
# mean_score_time          0.0777951
# std_score_time           0.00159606
# param_max_depth          2
# param_min_samples_split  800
# param_n_estimators       4
# params                   {'max_depth': 2, 'min_samples_split': 800, 'n_estimators': 4}
# split0_test_score       -4.50467e+14
# split1_test_score       -2.39396e+15
# split2_test_score       -1.57185e+15
# split3_test_score       -3.37624e+15
# split4_test_score       -5.4402e+14
# mean_test_score         -1.66731e+15
# std_test_score           1.11356e+15
# rank_test_score          357
# split0_train_score      -1.53017e+15
# split1_train_score      -1.12127e+15
# split2_train_score      -1.23887e+15
# split3_train_score      -8.08056e+14
# split4_train_score      -1.21271e+15
# mean_train_score        -1.18222e+15
# std_train_score          2.31916e+14
#
#                                                                                     17  \
# mean_fit_time            10.336
# std_fit_time             0.185719
# mean_score_time          0.0843895
# std_score_time           0.00307326
# param_max_depth          2
# param_min_samples_split  800
# param_n_estimators       6
# params                   {'max_depth': 2, 'min_samples_split': 800, 'n_estimators': 6}
# split0_test_score       -5.12626e+14
# split1_test_score       -2.68615e+15
# split2_test_score       -1.44415e+15
# split3_test_score       -3.0963e+15
# split4_test_score       -6.13805e+14
# mean_test_score         -1.6706e+15
# std_test_score           1.05574e+15
# rank_test_score          373
# split0_train_score      -1.60386e+15
# split1_train_score      -1.09866e+15
# split2_train_score      -1.2695e+15
# split3_train_score      -9.02818e+14
# split4_train_score      -1.28395e+15
# mean_train_score        -1.23176e+15
# std_train_score          2.31743e+14
#
#                                                                                     18  \
# mean_fit_time            13.44
# std_fit_time             0.0889109
# mean_score_time          0.0929948
# std_score_time           0.00352705
# param_max_depth          2
# param_min_samples_split  800
# param_n_estimators       8
# params                   {'max_depth': 2, 'min_samples_split': 800, 'n_estimators': 8}
# split0_test_score       -4.47094e+14
# split1_test_score       -2.71544e+15
# split2_test_score       -1.48425e+15
# split3_test_score       -2.93467e+15
# split4_test_score       -6.98748e+14
# mean_test_score         -1.65604e+15
# std_test_score           1.01634e+15
# rank_test_score          347
# split0_train_score      -1.48606e+15
# split1_train_score      -1.14631e+15
# split2_train_score      -1.31698e+15
# split3_train_score      -9.41899e+14
# split4_train_score      -1.37131e+15
# mean_train_score        -1.25251e+15
# std_train_score          1.90038e+14
#
#                                                                                      19  \
# mean_fit_time            16.612
# std_fit_time             0.0478177
# mean_score_time          0.103995
# std_score_time           0.00429492
# param_max_depth          2
# param_min_samples_split  800
# param_n_estimators       10
# params                   {'max_depth': 2, 'min_samples_split': 800, 'n_estimators': 10}
# split0_test_score       -4.38745e+14
# split1_test_score       -2.66562e+15
# split2_test_score       -1.46375e+15
# split3_test_score       -2.7681e+15
# split4_test_score       -6.60619e+14
# mean_test_score         -1.59937e+15
# std_test_score           9.74629e+14
# rank_test_score          321
# split0_train_score      -1.44603e+15
# split1_train_score      -1.12627e+15
# split2_train_score      -1.31983e+15
# split3_train_score      -9.54534e+14
# split4_train_score      -1.39719e+15
# mean_train_score        -1.24877e+15
# std_train_score          1.83067e+14
#
#                                                                                      20  \
# mean_fit_time            3.67701
# std_fit_time             0.0157843
# mean_score_time          0.0669896
# std_score_time           0.00167486
# param_max_depth          2
# param_min_samples_split  1000
# param_n_estimators       2
# params                   {'max_depth': 2, 'min_samples_split': 1000, 'n_estimators': 2}
# split0_test_score       -5.09289e+14
# split1_test_score       -2.88362e+15
# split2_test_score       -1.62192e+15
# split3_test_score       -3.926e+15
# split4_test_score       -6.58881e+14
# mean_test_score         -1.91994e+15
# std_test_score           1.31316e+15
# rank_test_score          441
# split0_train_score      -1.76258e+15
# split1_train_score      -1.35792e+15
# split2_train_score      -1.28842e+15
# split3_train_score      -1.10149e+15
# split4_train_score      -1.44118e+15
# mean_train_score        -1.39032e+15
# std_train_score          2.17265e+14
#
#                                                                                      21  \
# mean_fit_time            6.96861
# std_fit_time             0.041787
# mean_score_time          0.0765893
# std_score_time           0.00349724
# param_max_depth          2
# param_min_samples_split  1000
# param_n_estimators       4
# params                   {'max_depth': 2, 'min_samples_split': 1000, 'n_estimators': 4}
# split0_test_score       -4.50467e+14
# split1_test_score       -2.39396e+15
# split2_test_score       -1.57185e+15
# split3_test_score       -3.37624e+15
# split4_test_score       -5.4402e+14
# mean_test_score         -1.66731e+15
# std_test_score           1.11356e+15
# rank_test_score          357
# split0_train_score      -1.53017e+15
# split1_train_score      -1.12127e+15
# split2_train_score      -1.23887e+15
# split3_train_score      -8.08056e+14
# split4_train_score      -1.21271e+15
# mean_train_score        -1.18222e+15
# std_train_score          2.31916e+14
#
#                                                                                      22  \
# mean_fit_time            10.2366
# std_fit_time             0.169902
# ...
# split1_train_score      -9.65726e+14
# split2_train_score      -1.12331e+15
# split3_train_score      -7.29225e+14
# split4_train_score      -1.14446e+15
# mean_train_score        -1.08219e+15
# std_train_score          2.35663e+14
#
#                                                                                      443  \
# mean_fit_time            46.5198
# std_fit_time             0.970991
# mean_score_time          0.1304
# std_score_time           0.00564304
# param_max_depth          18
# param_min_samples_split  1800
# param_n_estimators       8
# params                   {'max_depth': 18, 'min_samples_split': 1800, 'n_estimators': 8}
# split0_test_score       -2.68989e+14
# split1_test_score       -2.59173e+15
# split2_test_score       -1.33076e+15
# split3_test_score       -2.78587e+15
# split4_test_score       -5.77093e+14
# mean_test_score         -1.51089e+15
# std_test_score           1.02377e+15
# rank_test_score          209
# split0_train_score      -1.32151e+15
# split1_train_score      -1.01481e+15
# split2_train_score      -1.17847e+15
# split3_train_score      -7.8251e+14
# split4_train_score      -1.23749e+15
# mean_train_score        -1.10696e+15
# std_train_score          1.90757e+14
#
#                                                                                       444  \
# mean_fit_time            58.0138
# std_fit_time             1.13749
# mean_score_time          0.1408
# std_score_time           0.00193897
# param_max_depth          18
# param_min_samples_split  1800
# param_n_estimators       10
# params                   {'max_depth': 18, 'min_samples_split': 1800, 'n_estimators': 10}
# split0_test_score       -2.32458e+14
# split1_test_score       -2.53779e+15
# split2_test_score       -1.3122e+15
# split3_test_score       -2.62707e+15
# split4_test_score       -5.32793e+14
# mean_test_score         -1.44846e+15
# std_test_score           9.91105e+14
# rank_test_score          73
# split0_train_score      -1.26041e+15
# split1_train_score      -9.90384e+14
# split2_train_score      -1.18185e+15
# split3_train_score      -8.03637e+14
# split4_train_score      -1.25861e+15
# mean_train_score        -1.09898e+15
# std_train_score          1.77443e+14
#
#                                                                                      445  \
# mean_fit_time            11.9098
# std_fit_time             0.640837
# mean_score_time          0.0790004
# std_score_time           0.00352138
# param_max_depth          18
# param_min_samples_split  2000
# param_n_estimators       2
# params                   {'max_depth': 18, 'min_samples_split': 2000, 'n_estimators': 2}
# split0_test_score       -2.45349e+14
# split1_test_score       -2.74349e+15
# split2_test_score       -1.33981e+15
# split3_test_score       -3.7207e+15
# split4_test_score       -5.60709e+14
# mean_test_score         -1.72201e+15
# std_test_score           1.32011e+15
# rank_test_score          424
# split0_train_score      -1.51779e+15
# split1_train_score      -1.20327e+15
# split2_train_score      -1.05187e+15
# split3_train_score      -8.84408e+14
# split4_train_score      -1.33968e+15
# mean_train_score        -1.1994e+15
# std_train_score          2.20023e+14
#
#                                                                                      446  \
# mean_fit_time            23.5246
# std_fit_time             0.7773
# mean_score_time          0.0926007
# std_score_time           0.00120013
# param_max_depth          18
# param_min_samples_split  2000
# param_n_estimators       4
# params                   {'max_depth': 18, 'min_samples_split': 2000, 'n_estimators': 4}
# split0_test_score       -2.79727e+14
# split1_test_score       -2.24048e+15
# split2_test_score       -1.38618e+15
# split3_test_score       -3.23048e+15
# split4_test_score       -3.92389e+14
# mean_test_score         -1.50585e+15
# std_test_score           1.11996e+15
# rank_test_score          188
# split0_train_score      -1.37097e+15
# split1_train_score      -9.56641e+14
# split2_train_score      -1.07306e+15
# split3_train_score      -6.51231e+14
# split4_train_score      -1.04861e+15
# mean_train_score        -1.0201e+15
# std_train_score          2.31007e+14
#
#                                                                                      447  \
# mean_fit_time            35.1874
# std_fit_time             0.955785
# mean_score_time          0.113201
# std_score_time           0.00475051
# param_max_depth          18
# param_min_samples_split  2000
# param_n_estimators       6
# params                   {'max_depth': 18, 'min_samples_split': 2000, 'n_estimators': 6}
# split0_test_score       -3.46846e+14
# split1_test_score       -2.56137e+15
# split2_test_score       -1.28298e+15
# split3_test_score       -2.93386e+15
# split4_test_score       -4.86372e+14
# mean_test_score         -1.52228e+15
# std_test_score           1.05681e+15
# rank_test_score          300
# split0_train_score      -1.44836e+15
# split1_train_score      -9.65834e+14
# split2_train_score      -1.12366e+15
# split3_train_score      -7.29284e+14
# split4_train_score      -1.1452e+15
# mean_train_score        -1.08247e+15
# std_train_score          2.35733e+14
#
#                                                                                      448  \
# mean_fit_time            46.427
# std_fit_time             1.08385
# mean_score_time          0.128601
# std_score_time           0.0050443
# param_max_depth          18
# param_min_samples_split  2000
# param_n_estimators       8
# params                   {'max_depth': 18, 'min_samples_split': 2000, 'n_estimators': 8}
# split0_test_score       -2.69058e+14
# split1_test_score       -2.59031e+15
# split2_test_score       -1.33306e+15
# split3_test_score       -2.78609e+15
# split4_test_score       -5.77293e+14
# mean_test_score         -1.51116e+15
# std_test_score           1.02339e+15
# rank_test_score          223
# split0_train_score      -1.32149e+15
# split1_train_score      -1.01508e+15
# split2_train_score      -1.17873e+15
# split3_train_score      -7.8252e+14
# split4_train_score      -1.2378e+15
# mean_train_score        -1.10712e+15
# std_train_score          1.90785e+14
#
#                                                                                       449
# mean_fit_time            58.5064
# std_fit_time             1.15951
# mean_score_time          0.144001
# std_score_time           0.00309872
# param_max_depth          18
# param_min_samples_split  2000
# param_n_estimators       10
# params                   {'max_depth': 18, 'min_samples_split': 2000, 'n_estimators': 10}
# split0_test_score       -2.32534e+14
# split1_test_score       -2.53671e+15
# split2_test_score       -1.31514e+15
# split3_test_score       -2.62647e+15
# split4_test_score       -5.32724e+14
# mean_test_score         -1.44872e+15
# std_test_score           9.90639e+14
# rank_test_score          88
# split0_train_score      -1.26042e+15
# split1_train_score      -9.90944e+14
# split2_train_score      -1.18225e+15
# split3_train_score      -8.02991e+14
# split4_train_score      -1.2589e+15
# mean_train_score        -1.0991e+15
# std_train_score          1.7768e+14

# %%
# Results with rank 1
rank_one = results_df[results_df['rank_test_score'] == 1][['params', 'mean_fit_time', 'std_fit_time', 'mean_train_score', 'std_train_score', 'mean_test_score', 'std_test_score']]
rank_one = pd.concat([rank_one['params'].apply(pd.Series), rank_one], axis = 1, sort=True).drop(columns = 'params')
rank_one.T
# Out:
#                             159
# max_depth          8.000000e+00
# min_samples_split  4.000000e+02
# n_estimators       1.000000e+01
# mean_fit_time      6.013399e+01
# std_fit_time       9.322278e-01
# mean_train_score  -9.652872e+14
# std_train_score    1.734750e+14
# mean_test_score   -1.299687e+15
# std_test_score     9.934932e+14

# %%
gridSearchResult.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=8,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=400,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
start = time.time()

model = gridSearchResult.best_estimator_.fit(train_X, train_y)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
time_taken = "{:0>2}:{:0>2}:{:05.3f}".format(int(hours),int(minutes),seconds)

# %%
predictions = pd.Series(model.predict(test_X))

# %%
print("Mean Squared Error:", (mean_squared_error(test_y, predictions))**0.5)
print("Time Taken to Fit:", time_taken)
# Out:
# Mean Squared Error: 20470409.099497728
# Time Taken to Fit: 00:01:2.378

# %%
fig = plt.figure(figsize=(30,8))
ax = plt.axes()

ax.plot(predictions.index, predictions, color = 'blue', label='Prediction')
ax.scatter(test_y.index, test_y, color = 'red', label='Real Value')

ax.legend(loc='best')
plt.show()
